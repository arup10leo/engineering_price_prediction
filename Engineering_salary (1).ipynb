# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/salary_engineering_Data.csv')

# %%
df.head()
# Out:
#        ID Gender  10percentage                       10board  12graduation  \
# 0  604399      f         87.80                          cbse          2017
# 1  988334      m         57.00                          cbse          2018
# 2  301647      m         77.33  maharashtra state board,pune          2015
# 3  582313      m         84.30                          cbse          2017
# 4  339001      f         82.00                          cbse          2016
#
#    12percentage                    12board  CollegeID  CollegeTier  \
# 0         84.00                       cbse       6920            1
# 1         64.50                       cbse       6624            2
# 2         85.17  amravati divisional board       9084            2
# 3         86.00                       cbse       8195            1
# 4         75.00                       cbse       4889            2
#
#         Degree  ...   CollegeState  GraduationYear  English  Logical Quant  \
# ...

# %%
df.describe()
# Out:
#                  ID  10percentage  12graduation  12percentage     CollegeID  \
# count  2.998000e+03   2998.000000   2998.000000   2998.000000   2998.000000
# mean   6.648926e+05     77.666264   2016.080720     74.341061   5210.210807
# std    3.648951e+05     10.002785      1.631814     11.120299   4776.609877
# min    1.124400e+04     43.000000   2006.000000     40.000000      2.000000
# 25%    3.334648e+05     71.140000   2015.000000     66.000000    526.250000
# 50%    6.396945e+05     78.965000   2016.000000     74.000000   4027.500000
# 75%    9.951770e+05     85.600000   2017.000000     82.600000   8822.250000
# max    1.297877e+06     97.760000   2020.000000     98.700000  18409.000000
#
#        CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count  2998.000000  2998.000000    2998.000000      2998.000000
# mean      1.924616    71.509857    5210.210807         0.296197
# std       0.264053     8.122462    4776.609877         0.456655
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       2998 non-null   int64
#  1   Gender                   2998 non-null   object
#  2   10percentage             2998 non-null   float64
#  3   10board                  2998 non-null   object
#  4   12graduation             2998 non-null   int64
#  5   12percentage             2998 non-null   float64
#  6   12board                  2998 non-null   object
#  7   CollegeID                2998 non-null   int64
#  8   CollegeTier              2998 non-null   int64
#  9   Degree                   2998 non-null   object
#  10  Specialization           2998 non-null   object
#  11  collegeGPA               2998 non-null   float64
#  12  CollegeCityID            2998 non-null   int64
#  13  CollegeCityTier          2998 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# ID                         0
# Gender                     0
# 10percentage               0
# 10board                    0
# 12graduation               0
# 12percentage               0
# 12board                    0
# CollegeID                  0
# CollegeTier                0
# Degree                     0
# Specialization             0
# collegeGPA                 0
# CollegeCityID              0
# CollegeCityTier            0
# CollegeState               0
# GraduationYear             0
# English                    0
# Logical                    0
# Quant                      0
# Domain                     0
# Salary                     0
# conscientiousness          0
# openess_to_experience      0
# openess_to_experience.1    0
# dtype: int64

# %%
df.drop(columns=['ID','CollegeCityID','CollegeCityTier','CollegeID','openess_to_experience.1'],inplace=True)

# %%
df.replace(-1, np.NaN,inplace=True)

# %%
# lets check the missing values again
df.isnull().sum()
# Out:
# Gender                     0
# 10percentage               0
# 10board                    0
# 12graduation               0
# 12percentage               0
# 12board                    0
# CollegeTier                0
# Degree                     0
# Specialization             0
# collegeGPA                 0
# CollegeState               0
# GraduationYear             0
# English                    0
# Logical                    0
# Quant                      0
# Domain                   179
# Salary                     0
# conscientiousness          0
# openess_to_experience      0
# dtype: int64

# %%
df.head()
# Out:
#   Gender  10percentage                       10board  12graduation  \
# 0      f         87.80                          cbse          2017
# 1      m         57.00                          cbse          2018
# 2      m         77.33  maharashtra state board,pune          2015
# 3      m         84.30                          cbse          2017
# 4      f         82.00                          cbse          2016
#
#    12percentage                    12board  CollegeTier       Degree  \
# 0         84.00                       cbse            1  B.Tech/B.E.
# 1         64.50                       cbse            2  B.Tech/B.E.
# 2         85.17  amravati divisional board            2  B.Tech/B.E.
# 3         86.00                       cbse            1  B.Tech/B.E.
# 4         75.00                       cbse            2  B.Tech/B.E.
#
#                             Specialization  collegeGPA   CollegeState  \
# 0  instrumentation and control engineering       73.82          Delhi
# ...

# %%
# df['Domain']=df['Domain'].fillna(df['Domain'].mean())
# df['collegeGPA']=df['collegeGPA'].fillna(df['collegeGPA'].mean())

# %%
df.isna().sum()
# Out:
# Gender                     0
# 10percentage               0
# 10board                    0
# 12graduation               0
# 12percentage               0
# 12board                    0
# CollegeTier                0
# Degree                     0
# Specialization             0
# collegeGPA                 0
# CollegeState               0
# GraduationYear             0
# English                    0
# Logical                    0
# Quant                      0
# Domain                   179
# Salary                     0
# conscientiousness          0
# openess_to_experience      0
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# m    2282
# f     716
# Name: Gender, dtype: int64

# %%
df['Gender'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2998 entries, 0 to 2997
# Series name: Gender
# Non-Null Count  Dtype
# --------------  -----
# 2998 non-null   object
# dtypes: object(1)
# memory usage: 23.5+ KB

# %%
def gender(x):
  if x in 'f':
    return 0
  else:
    return 1

# %%
#converting gender to 0 for Female and 1 for Male

# %%
df['Gender']=df['Gender'].apply(gender)

# %%
df['Gender'].astype('int')
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 2993    0
# 2994    0
# 2995    1
# 2996    1
# 2997    1
# Name: Gender, Length: 2998, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 2998 non-null   int64
#  1   10percentage           2998 non-null   float64
#  2   10board                2998 non-null   object
#  3   12graduation           2998 non-null   int64
#  4   12percentage           2998 non-null   float64
#  5   12board                2998 non-null   object
#  6   CollegeTier            2998 non-null   int64
#  7   Degree                 2998 non-null   object
#  8   Specialization         2998 non-null   object
#  9   collegeGPA             2998 non-null   float64
#  10  CollegeState           2998 non-null   object
#  11  GraduationYear         2998 non-null   int64
#  12  English                2998 non-null   int64
#  13  Logical                2998 non-null   int64
# ...

# %%
df.head()
# Out:
#    Gender  10percentage                       10board  12graduation  \
# 0       0         87.80                          cbse          2017
# 1       1         57.00                          cbse          2018
# 2       1         77.33  maharashtra state board,pune          2015
# 3       1         84.30                          cbse          2017
# 4       0         82.00                          cbse          2016
#
#    12percentage                    12board  CollegeTier       Degree  \
# 0         84.00                       cbse            1  B.Tech/B.E.
# 1         64.50                       cbse            2  B.Tech/B.E.
# 2         85.17  amravati divisional board            2  B.Tech/B.E.
# 3         86.00                       cbse            1  B.Tech/B.E.
# 4         75.00                       cbse            2  B.Tech/B.E.
#
#                             Specialization  collegeGPA   CollegeState  \
# ...

# %%
sns.scatterplot(y=df['Gender'],x=df['Salary'])
# Out:
# <Axes: xlabel='Salary', ylabel='Gender'>

# %%
sns.boxplot(x=df['Gender'],y=df['Salary'])
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %%
#male engineers edges ahead in terms of good salaries but having almost same average salaries

# %%
sns.scatterplot(x=df['10percentage'],y=df['Salary'])
# Out:
# <Axes: xlabel='10percentage', ylabel='Salary'>

# %%
#as 10th percententage increases it somewhat effects salary, as it increase. Weak correlation.

# %%
sns.displot(df['12graduation'])

# %%
#most of them recently completed their high schools

# %%
sns.scatterplot(x = df['10percentage'], y = df['12percentage'])
# Out:
# <Axes: xlabel='10percentage', ylabel='12percentage'>

# %%
#case of multicollinearity may be present as it can be seen good % in 10th also leading to good % in 12th

# %%
df.head()
# Out:
#    Gender  10percentage                       10board  12graduation  \
# 0       0         87.80                          cbse          2017
# 1       1         57.00                          cbse          2018
# 2       1         77.33  maharashtra state board,pune          2015
# 3       1         84.30                          cbse          2017
# 4       0         82.00                          cbse          2016
#
#    12percentage                    12board  CollegeTier       Degree  \
# 0         84.00                       cbse            1  B.Tech/B.E.
# 1         64.50                       cbse            2  B.Tech/B.E.
# 2         85.17  amravati divisional board            2  B.Tech/B.E.
# 3         86.00                       cbse            1  B.Tech/B.E.
# 4         75.00                       cbse            2  B.Tech/B.E.
#
#                             Specialization  collegeGPA   CollegeState  \
# ...

# %%
df['10board'].value_counts()
# Out:
# cbse                            1026
# state board                      881
# 0                                256
# icse                             213
# ssc                               96
#                                 ...
# maharashtra state board,pune       1
# up board , allahabad               1
# mirza ahmed ali baig               1
# aurangabad board                   1
# karnataka education board          1
# Name: 10board, Length: 221, dtype: int64

# %%
def boards(x):
  if x != 'cbse' and x!='icse' and x!='ssc' and x!='state board':
    return 'others'
  else:
     return x
df['10board']=df['10board'].apply(boards)
df['12board']=df['12board'].apply(boards)

# %%
df['12board'].value_counts()
# Out:
# cbse           1039
# state board     948
# others          904
# icse            101
# ssc               6
# Name: 12board, dtype: int64

# %%
#taking down boards to 5 in 10th and 12th

# %%
sns.scatterplot(y = df['12percentage'], x = df['CollegeTier'])
# Out:
# <Axes: xlabel='CollegeTier', ylabel='12percentage'>

# %%
#comparitively lesser students in college 1 tier having lowest 12 percentage greater than the college tier 2's lowest %

# %%
sns.distplot(df['CollegeTier'])
# Out:
# <ipython-input-40-eea799e26207>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CollegeTier'])
# <Axes: xlabel='CollegeTier', ylabel='Density'>

# %%
sns.scatterplot(x=df['Salary'],y=df['CollegeTier'])
# Out:
# <Axes: xlabel='Salary', ylabel='CollegeTier'>

# %%
#students from tier 2 grabbed good packages

# %%
df['Degree'].value_counts()
# Out:
# B.Tech/B.E.      2757
# MCA               200
# M.Tech./M.E.       40
# M.Sc. (Tech.)       1
# Name: Degree, dtype: int64

# %%
def degree(x):
  if x != 'B.Tech/B.E.' and x!='MCA' and x!='M.Tech./M.E.' :
    return 'others'
  else:
     return x

# %%
df['Degrees']=df['Degree'].apply(degree)

# %%
df.drop(columns=['Degree'],inplace=True)

# %%
sns.scatterplot(x=df['Salary'],y=df['Degrees'])
# Out:
# <Axes: xlabel='Salary', ylabel='Degrees'>

# %%
#B.Tech holders package is high.

# %%
df['Specialization'].value_counts()
# Out:
# electronics and communication engineering      670
# computer science & engineering                 557
# information technology                         506
# computer engineering                           415
# computer application                           201
# mechanical engineering                         155
# electronics and electrical engineering         148
# electronics & telecommunications                89
# electrical engineering                          63
# electronics & instrumentation eng               24
# instrumentation and control engineering         18
# information science engineering                 18
# electronics and instrumentation engineering     18
# civil engineering                               15
# electronics engineering                         13
# biotechnology                                   12
# other                                           10
# industrial & production engineering              8
# ...

# %%
data = df.copy()

value_count = data['Specialization'].value_counts()

def map_to_other_specialization(var):
    if value_count[var]<=10:
         return 'others'
    else:
         return var

#apply the function to specialization to get the results
df['Specializations'] = df['Specialization'].apply(map_to_other_specialization)

# %%
df.head()
# Out:
#    Gender  10percentage 10board  12graduation  12percentage 12board  \
# 0       0         87.80    cbse          2017         84.00    cbse
# 1       1         57.00    cbse          2018         64.50    cbse
# 2       1         77.33  others          2015         85.17  others
# 3       1         84.30    cbse          2017         86.00    cbse
# 4       0         82.00    cbse          2016         75.00    cbse
#
#    CollegeTier                           Specialization  collegeGPA  \
# 0            1  instrumentation and control engineering       73.82
# 1            2           computer science & engineering       65.00
# 2            2         electronics & telecommunications       61.94
# 3            1           computer science & engineering       80.40
# 4            2                            biotechnology       64.30
#
#     CollegeState  GraduationYear  English  Logical  Quant    Domain  Salary  \
# ...

# %%
df.drop(columns=['Specialization'],inplace=True)

# %%
df['Specializations'].value_counts()
# Out:
# electronics and communication engineering      670
# computer science & engineering                 557
# information technology                         506
# computer engineering                           415
# computer application                           201
# mechanical engineering                         155
# electronics and electrical engineering         148
# electronics & telecommunications                89
# others                                          76
# electrical engineering                          63
# electronics & instrumentation eng               24
# electronics and instrumentation engineering     18
# instrumentation and control engineering         18
# information science engineering                 18
# civil engineering                               15
# electronics engineering                         13
# biotechnology                                   12
# Name: Specializations, dtype: int64

# %%
sns.scatterplot(y = 'Specializations', x = 'Salary', hue = 'CollegeTier',palette='dark', data = df)
# Out:
# <Axes: xlabel='Salary', ylabel='Specializations'>

# %%
#plot shows even from tier 2 colleges, students with IT feilds, payed good packages whereas core branches suffers in tier 2

# %%
# count plot of unique categories in specialization
sns.countplot(y=df['Specializations'],data=df)

plt.show()

# %%
df['Specializations']=df['Specializations'].str.replace('electronics & instrumentation eng','electronics and instrumentation engineering')

# %%
#both were same branches

# %%
special=df.groupby('Specializations').agg(mean=('Salary','mean')).sort_values(by = 'mean',ascending=False)
sns.barplot(y=special.index,x='mean',data=special)
plt.show()

# %%
df.head()
# Out:
#    Gender  10percentage 10board  12graduation  12percentage 12board  \
# 0       0         87.80    cbse          2017         84.00    cbse
# 1       1         57.00    cbse          2018         64.50    cbse
# 2       1         77.33  others          2015         85.17  others
# 3       1         84.30    cbse          2017         86.00    cbse
# 4       0         82.00    cbse          2016         75.00    cbse
#
#    CollegeTier  collegeGPA   CollegeState  GraduationYear  English  Logical  \
# 0            1       73.82          Delhi            2021      650      665
# 1            2       65.00  Uttar Pradesh            2022      440      435
# 2            2       61.94    Maharashtra            2019      485      475
# 3            1       80.40          Delhi            2021      675      620
# 4            2       64.30     Tamil Nadu            2020      575      495
#
#    Quant    Domain  Salary  conscientiousness  openess_to_experience  \
# ...

# %%
sns.boxplot(df['collegeGPA'])
# Out:
# <Axes: >

# %%
sns.scatterplot(y=df['collegeGPA'],x=df['Salary'])
# Out:
# <Axes: xlabel='Salary', ylabel='collegeGPA'>

# %%
#outliers present, needs to be treated by imputation

# %%
q1=df['collegeGPA'].quantile(0.25)
q3=df['collegeGPA'].quantile(0.75)
q1
iqr=q3-q1

upper=q3+1.5*iqr
lower=q1-1.5*iqr
upper,lower
# Out:
# (90.95499999999998, 51.87500000000001)

# %%
def out(x):
  if x > upper:
    x=upper
  elif x<lower:
    x=lower
  else:
    return x
df['collegeGPA']=df['collegeGPA'].apply(out)

# %%
sns.scatterplot(y=df['collegeGPA'],x=df['Salary'])
# Out:
# <Axes: xlabel='Salary', ylabel='collegeGPA'>

# %%
#70-75 college GPA bags high salaries, while 75-90 decreases a bit indicating they might opted for higher studies, while low GPA got min salaries

# %%
df['CollegeState'].value_counts()
# Out:
# Uttar Pradesh        698
# Karnataka            281
# Tamil Nadu           264
# Telangana            249
# Maharashtra          189
# Andhra Pradesh       172
# West Bengal          145
# Madhya Pradesh       144
# Punjab               141
# Haryana              136
# Orissa               130
# Rajasthan            126
# Delhi                122
# Uttarakhand           81
# Kerala                24
# Jharkhand             20
# Gujarat               18
# Chhattisgarh          17
# Himachal Pradesh      13
# Bihar                  8
# Union Territory        5
# Jammu and Kashmir      5
# Assam                  5
# Sikkim                 2
# Meghalaya              2
# Goa                    1
# Name: CollegeState, dtype: int64

# %%
df.head()
# Out:
#    Gender  10percentage 10board  12graduation  12percentage 12board  \
# 0       0         87.80    cbse          2017         84.00    cbse
# 1       1         57.00    cbse          2018         64.50    cbse
# 2       1         77.33  others          2015         85.17  others
# 3       1         84.30    cbse          2017         86.00    cbse
# 4       0         82.00    cbse          2016         75.00    cbse
#
#    CollegeTier  collegeGPA   CollegeState  GraduationYear  English  Logical  \
# 0            1       73.82          Delhi            2021      650      665
# 1            2       65.00  Uttar Pradesh            2022      440      435
# 2            2       61.94    Maharashtra            2019      485      475
# 3            1       80.40          Delhi            2021      675      620
# 4            2       64.30     Tamil Nadu            2020      575      495
#
#    Quant    Domain  Salary  conscientiousness  openess_to_experience  \
# ...

# %%
plt.figure(figsize=(10,3))
sns.heatmap(df.corr()[['Salary']],annot=True)
# Out:
# <ipython-input-70-5511899eabb2>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr()[['Salary']],annot=True)
# <Axes: >

# %%
sns.displot(df['Salary'])

# %%
#salary right skewed so using log transformation as it bring these values into the center of the distribution

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 2998 non-null   int64
#  1   10percentage           2998 non-null   float64
#  2   10board                2998 non-null   object
#  3   12graduation           2998 non-null   int64
#  4   12percentage           2998 non-null   float64
#  5   12board                2998 non-null   object
#  6   CollegeTier            2998 non-null   int64
#  7   collegeGPA             2966 non-null   float64
#  8   CollegeState           2998 non-null   object
#  9   GraduationYear         2998 non-null   int64
#  10  English                2998 non-null   int64
#  11  Logical                2998 non-null   int64
#  12  Quant                  2998 non-null   int64
#  13  Domain                 2819 non-null   float64
# ...

# %%
df['Domain'].isna().sum()
# Out:
# 179

# %%
df['collegeGPA']=df['collegeGPA'].fillna(df['collegeGPA'].mean())
df['Domain']=df['Domain'].fillna(df['Domain'].mean())

# %%
#filling NAN values with mean

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2998 entries, 0 to 2997
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 2998 non-null   int64
#  1   10percentage           2998 non-null   float64
#  2   10board                2998 non-null   object
#  3   12graduation           2998 non-null   int64
#  4   12percentage           2998 non-null   float64
#  5   12board                2998 non-null   object
#  6   CollegeTier            2998 non-null   int64
#  7   collegeGPA             2998 non-null   float64
#  8   CollegeState           2998 non-null   object
#  9   GraduationYear         2998 non-null   int64
#  10  English                2998 non-null   int64
#  11  Logical                2998 non-null   int64
#  12  Quant                  2998 non-null   int64
#  13  Domain                 2998 non-null   float64
# ...

# %%
X = df.drop(columns=['Salary'])
y = np.log(df['Salary'])

# %%
#log transforming the salary column

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X, y, test_size=0.13, random_state=4)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2608 entries, 29 to 1146
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 2608 non-null   int64
#  1   10percentage           2608 non-null   float64
#  2   10board                2608 non-null   object
#  3   12graduation           2608 non-null   int64
#  4   12percentage           2608 non-null   float64
#  5   12board                2608 non-null   object
#  6   CollegeTier            2608 non-null   int64
#  7   collegeGPA             2608 non-null   float64
#  8   CollegeState           2608 non-null   object
#  9   GraduationYear         2608 non-null   int64
#  10  English                2608 non-null   int64
#  11  Logical                2608 non-null   int64
#  12  Quant                  2608 non-null   int64
#  13  Domain                 2608 non-null   float64
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[2,5,8,16,17])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)


print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# MAE 0.3429930685885176
# MSE 0.18774013235536743
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[2,5,8,16,17])
],remainder='passthrough')

step2 = step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# MAE 0.3404761819266611
# MSE 0.1861883452947405
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[2,5,8,16,17])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# MAE 0.3917083394352888
# MSE 0.24829917989535613
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
#KNN performed badly

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[2,5,8,16,17])
],remainder='passthrough')

step2 =SVR(kernel='rbf',C=10000,epsilon=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# MAE 0.35788806562906383
# MSE 0.19887950506817506
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
import pickle

pickle.dump(df,open('df4.pkl','wb'))
pickle.dump(pipe,open('pipe4.pkl','wb'))

# %% [markdown]
# Linear Regression yeilded good result
